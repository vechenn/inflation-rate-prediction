# %% [markdown]
# # Блокнот для сбора данных в единный фрейм, отбрасывание неправильно загруженных данных и неподходящих по дискретизации.

# %%
import pandas as pd
import os
import re

folder_path = "../data/external/features"
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
start_date_list = list()
end_date_list = list()
dataframes = []
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    if len(df) == 0:
        continue
    start_index = file.find("indicator_") + len("indicator_")
    end_index = file.rfind(".csv")
    substring = file[start_index:end_index].rstrip("_")

    df["Indicator"] = substring
    df["Filename"] = file

    df['DateTime'] = pd.to_datetime(df['DateTime'])
    df['DateTime'] = df['DateTime'].dt.normalize()
    df['DateTime'] = df['DateTime'].dt.to_period('M').dt.to_timestamp()

    start_time = df['DateTime'].min()
    end_time = df['DateTime'].max()
    if start_time > pd.to_datetime("2000-01-01") or end_time < pd.to_datetime("2025-01-01"):
        continue 
    start_date_list.append(start_time)
    end_date_list.append(end_time)

    df = df[["DateTime", "Close", "Frequency", "Indicator", "Filename"]].copy()

    dataframes.append(df)
    del df

df = pd.read_csv('../data/external/inflation_target/historical_country_United_States_indicator_inflation_rate.csv')
df.rename(columns={"Value" : "Close"}, inplace=True)
df["Indicator"] = "inflation_rate"
df["Filename"] = "historical_country_United_States_indicator_inflation_rate.csv"
df['DateTime'] = pd.to_datetime(df['DateTime'])
df['DateTime'] = df['DateTime'].dt.normalize()
df['DateTime'] = df['DateTime'].dt.to_period('M').dt.to_timestamp()
df = df[["DateTime", "Close", "Frequency", "Indicator", "Filename"]].copy()
dataframes.append(df)
del df 

full_data = pd.concat(dataframes, ignore_index=True)
full_data.rename(columns={"DateTime" : "Date"}, inplace=True)
full_data = full_data[full_data.Date >= pd.to_datetime("2000-07-01")].copy()

# %%
print(len(start_date_list), len(end_date_list), end="\n\n")
print(set(start_date_list), end="\n\n")
print(set(end_date_list))
# Out:
# 176 176
#
# {Timestamp('1981-12-01 00:00:00'), Timestamp('1914-01-01 00:00:00'), Timestamp('1997-02-01 00:00:00'), Timestamp('1992-03-01 00:00:00'), Timestamp('1964-01-01 00:00:00'), Timestamp('1996-01-01 00:00:00'), Timestamp('1976-06-01 00:00:00'), Timestamp('1983-09-01 00:00:00'), Timestamp('1969-01-01 00:00:00'), Timestamp('1982-06-01 00:00:00'), Timestamp('1919-02-01 00:00:00'), Timestamp('1959-01-01 00:00:00'), Timestamp('1938-12-01 00:00:00'), Timestamp('1991-01-01 00:00:00'), Timestamp('1952-11-01 00:00:00'), Timestamp('1955-01-01 00:00:00'), Timestamp('1964-02-01 00:00:00'), Timestamp('1963-02-01 00:00:00'), Timestamp('1993-05-01 00:00:00'), Timestamp('1968-05-01 00:00:00'), Timestamp('1967-01-01 00:00:00'), Timestamp('1993-01-01 00:00:00'), Timestamp('1971-04-01 00:00:00'), Timestamp('1954-01-01 00:00:00'), Timestamp('1994-01-01 00:00:00'), Timestamp('1992-02-01 00:00:00'), Timestamp('1942-01-01 00:00:00'), Timestamp('1978-01-01 00:00:00'), Timestamp('1987-12-01 00:00:00'), Timestamp('1985-01-01 00:00:00'), Timestamp('1993-11-01 00:00:00'), Timestamp('1987-07-01 00:00:00'), Timestamp('1960-01-01 00:00:00'), Timestamp('1979-01-01 00:00:00'), Timestamp('1984-09-01 00:00:00'), Timestamp('1990-01-01 00:00:00'), Timestamp('1957-02-01 00:00:00'), Timestamp('1982-08-01 00:00:00'), Timestamp('1976-01-01 00:00:00'), Timestamp('1991-02-01 00:00:00'), Timestamp('1989-01-01 00:00:00'), Timestamp('1980-01-01 00:00:00'), Timestamp('1959-02-01 00:00:00'), Timestamp('1986-12-01 00:00:00'), Timestamp('1909-12-01 00:00:00'), Timestamp('1948-01-01 00:00:00'), Timestamp('1982-09-01 00:00:00'), Timestamp('1968-02-01 00:00:00'), Timestamp('1951-02-01 00:00:00'), Timestamp('1939-01-01 00:00:00'), Timestamp('1977-10-01 00:00:00'), Timestamp('1960-02-01 00:00:00'), Timestamp('1973-01-01 00:00:00'), Timestamp('1985-09-01 00:00:00'), Timestamp('1939-02-01 00:00:00'), Timestamp('1984-06-01 00:00:00'), Timestamp('1958-01-01 00:00:00'), Timestamp('1991-08-01 00:00:00'), Timestamp('1963-01-01 00:00:00'), Timestamp('1950-01-01 00:00:00'), Timestamp('1947-01-01 00:00:00'), Timestamp('1957-01-01 00:00:00'), Timestamp('1975-01-01 00:00:00'), Timestamp('1992-01-01 00:00:00'), Timestamp('1950-03-01 00:00:00'), Timestamp('2000-01-01 00:00:00'), Timestamp('1968-01-01 00:00:00'), Timestamp('1971-08-01 00:00:00'), Timestamp('1947-02-01 00:00:00'), Timestamp('1999-01-01 00:00:00'), Timestamp('1979-02-01 00:00:00'), Timestamp('1967-03-01 00:00:00'), Timestamp('1943-02-01 00:00:00'), Timestamp('1998-01-01 00:00:00'), Timestamp('1983-12-01 00:00:00'), Timestamp('1978-05-01 00:00:00'), Timestamp('1986-02-01 00:00:00'), Timestamp('1920-01-01 00:00:00')}
#
# {Timestamp('2025-12-01 00:00:00'), Timestamp('2025-02-01 00:00:00'), Timestamp('2025-01-01 00:00:00'), Timestamp('2025-04-01 00:00:00'), Timestamp('2025-03-01 00:00:00')}

# %%
print(f"Количество файлов: {len(set(csv_files))}.")
print(f"Количество загруженных csv файлов: {len(dataframes) - 1}.")
print(f"Данные загружены из {len(full_data.Filename.unique())} файлов.")

if len(full_data.Filename.unique()) <= len(set(csv_files)):
    print(f"При загрузке отброшены файлы: {set(csv_files) - set(full_data.Filename.unique())}")
# Out:
# Количество файлов: 293.
# Количество загруженных csv файлов: 176.
# Данные загружены из 177 файлов.
# При загрузке отброшены файлы: {'historical_country_united_states_indicator_home_ownership_rate_.csv', 'historical_country_united_states_indicator_case_shiller_home_price_index_mom_.csv', 'historical_country_united_states_indicator_full_year_gdp_growth_.csv', 'historical_country_united_states_indicator_gdp_from_services_.csv', 'historical_country_united_states_indicator_producer_price_inflation_mom_.csv', 'historical_country_united_states_indicator_gross_national_product_.csv', 'historical_country_united_states_indicator_gdp_deflator_.csv', 'historical_country_united_states_indicator_productivity_.csv', 'historical_country_united_states_indicator_case_shiller_home_price_index_yoy_.csv', 'historical_country_united_states_indicator_gdp_from_utilities_.csv', 'historical_country_united_states_indicator_debt_balance_total_.csv', 'historical_country_united_states_indicator_changes_in_inventories_.csv', 'historical_country_united_states_indicator_ppi_ex_food_energy_and_trade_services_yoy_.csv', 'historical_country_united_states_indicator_cushing_crude_oil_stocks_.csv', 'historical_country_united_states_indicator_government_budget_.csv', 'historical_country_united_states_indicator_job_offers_.csv', 'historical_country_united_states_indicator_redbook_index_.csv', 'historical_country_united_states_indicator_pending_home_sales_.csv', 'historical_country_united_states_indicator_ppi_ex_food_energy_and_trade_services_.csv', 'historical_country_united_states_indicator_corporate_profits_.csv', 'historical_country_united_states_indicator_dallas_fed_services_revenues_index_.csv', 'historical_country_united_states_indicator_inflation_expectations_.csv', 'historical_country_united_states_indicator_residential_property_prices_.csv', 'historical_country_united_states_indicator_gdp_.csv', 'historical_country_united_states_indicator_population_.csv', 'historical_country_united_states_indicator_consumer_spending_.csv', 'historical_country_united_states_indicator_real_consumer_spending_.csv', 'historical_country_united_states_indicator_core_producer_prices_.csv', 'historical_country_united_states_indicator_producer_prices_.csv', 'historical_country_united_states_indicator_external_debt_.csv', 'historical_country_united_states_indicator_api_distillate_stocks_.csv', 'historical_country_united_states_indicator_retirement_age_men_.csv', 'historical_country_united_states_indicator_private_debt_to_gdp_.csv', 'historical_country_united_states_indicator_debt_balance_mortgages_.csv', 'historical_country_united_states_indicator_api_cushing_number_.csv', 'historical_country_united_states_indicator_gdp_from_construction_.csv', 'historical_country_united_states_indicator_gdp_from_public_administration_.csv', 'historical_country_united_states_indicator_hiring_plans_announcements_.csv', 'historical_country_united_states_indicator_terms_of_trade_.csv', 'historical_country_united_states_indicator_fed_capital_account_surplus_.csv', 'historical_country_united_states_indicator_gold_reserves_.csv', 'historical_country_united_states_indicator_unit_labour_costs_qoq_.csv', 'historical_country_united_states_indicator_government_spending_.csv', 'historical_country_united_states_indicator_government_debt_to_gdp_.csv', 'historical_country_united_states_indicator_terrorism_index_.csv', 'historical_country_united_states_indicator_kansas_fed_new_orders_index_.csv', 'historical_country_united_states_indicator_kansas_fed_prices_paid_index_.csv', 'historical_country_united_states_indicator_labour_costs_.csv', 'historical_country_united_states_indicator_central_bank_balance_sheet_.csv', 'historical_country_united_states_indicator_corruption_rank_.csv', 'historical_country_united_states_indicator_dallas_fed_manufacturing_prices_paid_index_.csv', 'historical_country_united_states_indicator_employment_cost_index_wages_.csv', 'historical_country_united_states_indicator_job_quits_.csv', 'historical_country_united_states_indicator_gdp_per_capita_ppp_.csv', 'historical_country_united_states_ind ...

# %%
for name in csv_files:
    if "inflation" in name:
        print(name)
# Out:
# historical_country_united_states_indicator_inflation_expectations_.csv
# historical_country_united_states_indicator_energy_inflation_.csv
# historical_country_united_states_indicator_michigan_inflation_expectations_.csv
# historical_country_united_states_indicator_services_inflation_.csv
# historical_country_united_states_indicator_michigan_5_year_inflation_expectations_.csv
# historical_country_united_states_indicator_rent_inflation_.csv
# historical_country_united_states_indicator_food_inflation_.csv
# historical_country_united_states_indicator_core_inflation_rate_.csv
# historical_country_united_states_indicator_core_inflation_rate_mom_.csv
# historical_country_united_states_indicator_producer_price_inflation_mom_.csv
# historical_country_united_states_indicator_inflation_rate_mom_.csv

# %%
print(full_data.shape, end="\n\n")
print(full_data.dtypes, end="\n\n")
print(full_data.describe, end="\n\n")
print(full_data.isna().sum())
# Out:
# (111698, 5)
#
# Date         datetime64[ns]
# Close               float64
# Frequency            object
# Indicator            object
# Filename             object
# dtype: object
#
# <bound method NDFrame.describe of              Date      Close Frequency         Indicator  \
# 54     2000-07-01  4947731.0   Monthly  tourist_arrivals
# 55     2000-08-01  4650387.0   Monthly  tourist_arrivals
# 56     2000-09-01  3874868.0   Monthly  tourist_arrivals
# 57     2000-10-01  3654971.0   Monthly  tourist_arrivals
# 58     2000-11-01  3206700.0   Monthly  tourist_arrivals
# ...           ...        ...       ...               ...
# 212752 2024-11-01        2.7   Monthly    inflation_rate
# 212753 2024-12-01        2.9   Monthly    inflation_rate
# 212754 2025-01-01        3.0   Monthly    inflation_rate
# 212755 2025-02-01        2.8   Monthly    inflation_rate
# 212756 2025-03-01        2.4   Monthly    inflation_rate
#
#                                                  Filename
# 54      historical_country_united_states_indicator_tou...
# 55      historical_country_united_states_indicator_tou...
# 56      historical_country_united_states_indicator_tou...
# 57      historical_country_united_states_indicator_tou...
# 58      historical_country_united_states_indicator_tou...
# ...                                                   ...
# 212752  historical_country_United_States_indicator_inf...
# 212753  historical_country_United_States_indicator_inf...
# 212754  historical_country_United_States_indicator_inf...
# 212755  historical_country_United_States_indicator_inf...
# 212756  historical_country_United_States_indicator_inf...
#
# [111698 rows x 5 columns]>
#
# Date         0
# Close        0
# Frequency    0
# Indicator    0
# Filename     0
# dtype: int64

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 111698 entries, 54 to 212756
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       111698 non-null  datetime64[ns]
#  1   Close      111698 non-null  float64
#  2   Frequency  111698 non-null  object
#  3   Indicator  111698 non-null  object
#  4   Filename   111698 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 5.1+ MB

# %%
full_data = full_data[full_data.Frequency != "Yearly"].copy()
full_data.rename(columns={"Close" : "Value"}, inplace=True)
del full_data["Filename"]

# %%
full_data.head()
# Out:
#          Date      Value Frequency         Indicator
# 54 2000-07-01  4947731.0   Monthly  tourist_arrivals
# 55 2000-08-01  4650387.0   Monthly  tourist_arrivals
# 56 2000-09-01  3874868.0   Monthly  tourist_arrivals
# 57 2000-10-01  3654971.0   Monthly  tourist_arrivals
# 58 2000-11-01  3206700.0   Monthly  tourist_arrivals

# %%
wide_full_data = full_data.pivot_table(index='Date', columns='Indicator', values='Value', aggfunc='mean').reset_index()

# %%
start = wide_full_data['Date'].min()
end = wide_full_data['Date'].max()
expected = pd.date_range(start=start, end=end, freq='MS')  # MS = Month Start
actual = pd.Series(wide_full_data['Date'].unique()).sort_values()
missing = expected.difference(actual)

if missing.empty:
    print("Все месяцы присутствуют.")
else:
    print("Пропущены месяцы:")
    print(missing)

wide_full_data.columns.name = None
wide_full_data = wide_full_data.set_index('Date')
wide_full_data = wide_full_data.sort_index()
# Out:
# Все месяцы присутствуют.

# %%
stats = wide_full_data.isna().sum()/len(wide_full_data)
stats[stats > 0.1]
# Out:
# Series([], dtype: float64)

# %%
wide_full_data.isna().sum().sort_values()
# Out:
# 15_year_mortgage_rate                   0
# continuing_jobless_claims               0
# philadelphia_fed_manufacturing_index    0
# nahb_housing_market_index               0
# crude_oil_rigs                          0
#                                        ..
# coincident_index                        3
# tourist_arrivals                        3
# national_home_price_index               3
# crude_oil_production                    3
# auto_exports                            3
# Length: 172, dtype: int64

# %%
wide_full_data = wide_full_data.interpolate(method='time', limit_area="inside")

for col in wide_full_data.columns:
    series = wide_full_data[col]
    num_tail_nans = series[::-1].isna().sum()
    if num_tail_nans > 0:
        wide_full_data[col] = series.shift(int(num_tail_nans))

wide_full_data = wide_full_data[wide_full_data.index >= pd.to_datetime("2001-01-01")]

# %%
wide_full_data.isna().sum().sort_values()
# Out:
# 15_year_mortgage_rate                     0
# michigan_5_year_inflation_expectations    0
# michigan_consumer_expectations            0
# michigan_current_economic_conditions      0
# michigan_inflation_expectations           0
#                                          ..
# export_prices                             0
# export_prices_mom                         0
# export_prices_yoy                         0
# effective_federal_funds_rate              0
# youth_unemployment_rate                   0
# Length: 172, dtype: int64

# %%
wide_full_data
# Out:
#             15_year_mortgage_rate  30_year_mortgage_rate  auto_exports  \
# Date
# 2001-01-01                 6.6400                 7.0325          67.0
# 2001-02-01                 6.6400                 7.0500          52.1
# 2001-03-01                 6.5080                 6.9520          47.0
# 2001-04-01                 6.5950                 7.0775          44.2
# 2001-05-01                 6.6960                 7.1640          52.2
# ...                           ...                    ...           ...
# 2024-12-01                 5.9300                 6.7150          72.9
# 2025-01-01                 6.1640                 6.9580          55.4
# 2025-02-01                 6.0300                 6.8425          68.7
# 2025-03-01                 5.8275                 6.6500          64.4
# 2025-04-01                 5.9025                 6.7250         101.1
#
#             average_house_prices  average_mortgage_size  balance_of_trade  \
# Date
# 2001-01-01              208100.0             163.857143           -32.242
# 2001-02-01              209000.0             162.756522           -32.258
# 2001-03-01              211000.0             160.110000           -35.202
# 2001-04-01              210200.0             159.509091           -29.300
# 2001-05-01              205500.0             159.542857           -32.811
# ...                          ...                    ...               ...
# 2024-12-01              478400.0             402.873000           -73.730
# 2025-01-01              509700.0             400.930000           -78.240
# 2025-02-01              510000.0             403.416000           -98.060
# 2025-03-01              487100.0             397.516000          -130.650
# 2025-04-01              497700.0             381.921000          -122.660
#
#             bank_lending_rate  banks_balance_sheet  building_permits  \
# Date
# 2001-01-01               9.50             6192.220            1543.0
# 2001-02-01               9.05             6143.275            1699.0
# 2001-03-01               8.50             6163.050            1656.0
# 2001-04-01               8.32             6224.075            1659.0
# 2001-05-01               7.80             6207.180            1666.0
# ...                       ...                  ...               ...
# 2024-12-01               7.75            23721.200            1493.0
# 2025-01-01               7.50            23693.400            1482.0
# 2025-02-01               7.50            23766.975            1473.0
# 2025-03-01               7.50            23975.150            1459.0
# 2025-04-01               7.50            24156.200            1467.0
#
#             building_permits_mom  ...  unemployed_persons  unemployment_rate  \
# Date                              ...
# 2001-01-01                  -4.4  ...              5634.0                3.9
# 2001-02-01                  10.1  ...              6023.0                4.2
# 2001-03-01                  -2.5  ...              6089.0                4.2
# 2001-04-01                   0.2  ...              6141.0                4.3
# 2001-05-01                   0.4  ...              6271.0                4.4
# ...                          ...  ...                 ...                ...
# 2024-12-01                   5.2  ...              7121.0                4.2
# 2025-01-01                  -0.7  ...              6886.0                4.1
# 2025-02-01                  -0.6  ...              6849.0                4.0
# 2025-03-01                  -1.0  ...              7052.0                4.1
# 2025-04-01                   0.5  ...              7083.0                4.2
#
#             used_car_prices_mom  used_car_prices_yoy  wage_growth  wages  \
# Date
# 2001-01-01                  0.2                  1.8         7.02  14.29
# 2001-02-01                  0.0                  2.5         5.52  14.29
# 2001-03-01                  0.1                  2.2         4.92  14.36
# 2001-04-01                 -0.7                  0.9         4.79  14.42
# 2001-05-01                 -0.2                  0.9         4.68  14.44
# ...                         ...                  ...          ...    ...
# 2024-12-01                  1.3                  0.2         5.00  30.58
# 2025-01-01                 -0.3                  0.4         5.12  30.67
# 2025-02-01                  0.4                  0.8         5.04  30.80
# 2025-03-01                 -0.7                  0.1         4.23  30.91
# 2025-04-01                 -0.7                 -0.2         3.54  30.96
#
#             wages_in_manufacturing  weekly_crude_oil_production  \
# Date
# 2001-01-01                   14.50                  5929.434783
# 2001-02-01                   14.48                  5884.750000
# 2001-03-01                   14.55                  5874.227273
# 2001-04-01                   14.59                  5867.380952
# 2001-05-01                   14.63                  5814.217391
# ...                            ...                          ...
# 2024-12-01                   28.22                 13598.250000
# 2025-01-01                   28.33                 13447.800000
# 2025-02-01                   28.58                 13500.250000
# 2025-03-01                   28.68                 13575.500000
# 2025-04-01                   28.92                 13460.000000
#
#             wholesale_inventories  youth_unemployment_rate
# Date
# 2001-01-01                    0.0                      9.2
# 2001-02-01                   -0.1                      9.6
# 2001-03-01                    0.1                      9.6
# 2001-04-01                    0.0                      9.8
# 2001-05-01                    0.5                     10.2
# ...                           ...                      ...
# 2024-12-01                   -0.1                      9.4
# 2025-01-01                   -0.4                      9.0
# 2025-02-01                    0.8                      9.0
# 2025-03-01                    0.5                      9.7
# 2025-04-01                    0.5                      9.4
#
# [292 rows x 172 columns]

# %%
columns_with_double_underscore = [col for col in wide_full_data.columns if '__' in col]
columns_with_triple_underscore = [col for col in wide_full_data.columns if '___' in col]
print(columns_with_double_underscore)
print(columns_with_triple_underscore)
# Out:
# ['continued_jobless_claims___federal_workers', 'jobless_claims___federal_workers']
# ['continued_jobless_claims___federal_workers', 'jobless_claims___federal_workers']

# %%
wide_full_data.columns = [col.replace('___', '_').replace('__', '_') for col in wide_full_data.columns]

# %%
columns_with_double_underscore = [col for col in wide_full_data.columns if '__' in col]
columns_with_triple_underscore = [col for col in wide_full_data.columns if '___' in col]
print(columns_with_double_underscore)
print(columns_with_triple_underscore)
# Out:
# []
# []

# %%
wide_full_data.to_csv("../data/interim/full_collected_data.csv")
